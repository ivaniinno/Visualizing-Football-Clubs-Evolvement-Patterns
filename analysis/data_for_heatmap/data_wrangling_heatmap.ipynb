# %%
import numpy as np
import pandas as pd
import json

# %%
# Load data about countries
countries_df = pd.read_json("../../parsing/parsedData/sorted_national_teams.json")
countries_df.head()
# Out:
#    NationalTeamID NationalTeamName                         Link_to_team  Page
# 0            3437        Аргентина  /argentinien/startseite/verein/3437     1
# 1            3377          Франция   /frankreich/startseite/verein/3377     1
# 2            3375          Испания      /spanien/startseite/verein/3375     1
# 3            3299           Англия      /england/startseite/verein/3299     1
# 4            3439         Бразилия    /brasilien/startseite/verein/3439     1

# %%
# Check axes
countries_df.axes
# Out:
# [RangeIndex(start=0, stop=210, step=1),
#  Index(['NationalTeamID', 'NationalTeamName', 'Link_to_team', 'Page'], dtype='object')]

# %%
# Drop "Link_to_team" and "Page" columns, we will not use them
countries_df.drop(["Link_to_team", "Page"], axis=1, inplace=True)
countries_df.head()
# Out:
#    NationalTeamID NationalTeamName
# 0            3437        Аргентина
# 1            3377          Франция
# 2            3375          Испания
# 3            3299           Англия
# 4            3439         Бразилия

# %%
# Check for missing values
countries_df.isna().sum()
# Out:
# NationalTeamID      0
# NationalTeamName    0
# dtype: int64

# %%
# Load data about clubs and their country belongings
clubs_df = pd.read_json("../../parsing/parsedData/sorted_teams.json")
clubs_df.head()
# Out:
#    TeamID       Team_name Country_Name  \
# 0     418     Реал Мадрид      Испания
# 1     281  Манчестер Сити       Англия
# 2      27         Бавария     Германия
# 3      31       Ливерпуль       Англия
# 4     583             ПСЖ      Франция
#
#                                     Link_to_team  Page
# 0             /real-madrid/startseite/verein/418     1
# 1         /manchester-city/startseite/verein/281     1
# 2        /fc-bayern-munchen/startseite/verein/27     1
# 3             /fc-liverpool/startseite/verein/31     1
# 4  /fc-paris-saint-germain/startseite/verein/583     1

# %%
# Check axes
clubs_df.axes
# Out:
# [RangeIndex(start=0, stop=536, step=1),
#  Index(['TeamID', 'Team_name', 'Country_Name', 'Link_to_team', 'Page'], dtype='object')]

# %%
# Drop "Link_to_team" and "Page" columns, we will not use them
clubs_df.drop(["Link_to_team", "Page"], axis=1, inplace=True)
clubs_df.head()
# Out:
#    TeamID       Team_name Country_Name
# 0     418     Реал Мадрид      Испания
# 1     281  Манчестер Сити       Англия
# 2      27         Бавария     Германия
# 3      31       Ливерпуль       Англия
# 4     583             ПСЖ      Франция

# %%
# Merge two data frames
countries_df = countries_df.merge(clubs_df, left_on="NationalTeamName", right_on="Country_Name")
countries_df.head(15)
# Out:
#     NationalTeamID NationalTeamName  TeamID    Team_name Country_Name
# 0             3377          Франция     583          ПСЖ      Франция
# 1             3377          Франция    1082        Лилль      Франция
# 2             3377          Франция     244      Марсель      Франция
# 3             3377          Франция     273         Ренн      Франция
# 4             3377          Франция    1041         Лион      Франция
# 5             3377          Франция     417        Ницца      Франция
# 6             3377          Франция    3911        Брест      Франция
# 7             3377          Франция     826         Ланс      Франция
# 8             3377          Франция     415       Тулуза      Франция
# 9             3377          Франция     995         Нант      Франция
# 10            3377          Франция    1421        Реймс      Франция
# 11            3377          Франция      40        Бордо      Франция
# 12            3377          Франция     618   Сент-Этьен      Франция
# 13            3377          Франция     667     Страсбур      Франция
# 14            3375          Испания     418  Реал Мадрид      Испания

# %%
# Drop club names, we will not need them
countries_df.drop(["Team_name"], axis=1, inplace=True)
countries_df.head(15)
# Out:
#     NationalTeamID NationalTeamName  TeamID Country_Name
# 0             3377          Франция     583      Франция
# 1             3377          Франция    1082      Франция
# 2             3377          Франция     244      Франция
# 3             3377          Франция     273      Франция
# 4             3377          Франция    1041      Франция
# 5             3377          Франция     417      Франция
# 6             3377          Франция    3911      Франция
# 7             3377          Франция     826      Франция
# 8             3377          Франция     415      Франция
# 9             3377          Франция     995      Франция
# 10            3377          Франция    1421      Франция
# 11            3377          Франция      40      Франция
# 12            3377          Франция     618      Франция
# 13            3377          Франция     667      Франция
# 14            3375          Испания     418      Испания

# %%
# Load complete data about clubs
complete_clubs_df = pd.read_json("../../parsing/parsedData/complete_clubs.json")
complete_clubs_df.head()
# Out:
#    TeamID   Year    TeamCost AverageAge  Legioners  TeamSize  \
# 0     1002  2014  4,25 млн €       21,5         16        39
# 1     1002  2015  3,60 млн €       21,6         12        32
# 2     1002  2016  3,48 млн €       21,0         10        38
# 3     1002  2017  3,55 млн €       21,3          8        37
# 4     1002  2018  5,80 млн €       22,4          9        39
#
#                                            PlayerIDS  NationalPlayersCount  \
# 0  [95621, 112797, 169963, 198986, 38793, 139304,...                    11
# 1  [112797, 169963, 198986, 38793, 133770, 133613...                     9
# 2  [112797, 169963, 198986, 324448, 133770, 13361...                    15
# 3  [112797, 169963, 198986, 324448, 363402, 13361...                    10
# 4  [198981, 112797, 169963, 198986, 324448, 36359...                    13
#
#    TeamSizeRatio
# 0            NaN
# 1           0.82
# 2           1.19
# 3           0.97
# 4           1.05

# %%
# Check axes
complete_clubs_df.axes
# Out:
# [RangeIndex(start=0, stop=5896, step=1),
#  Index(['TeamID ', 'Year', 'TeamCost', 'AverageAge', 'Legioners', 'TeamSize',
#         'PlayerIDS', 'NationalPlayersCount', 'TeamSizeRatio'],
#        dtype='object')]

# %%
# Remove redundant symbols from axes
complete_clubs_df.columns = complete_clubs_df.columns.str.strip()
complete_clubs_df.axes
# Out:
# [RangeIndex(start=0, stop=5896, step=1),
#  Index(['TeamID', 'Year', 'TeamCost', 'AverageAge', 'Legioners', 'TeamSize',
#         'PlayerIDS', 'NationalPlayersCount', 'TeamSizeRatio'],
#        dtype='object')]

# %%
# Check data types
complete_clubs_df.dtypes
# Out:
# TeamID                    int64
# Year                      int64
# TeamCost                 object
# AverageAge               object
# Legioners                 int64
# TeamSize                  int64
# PlayerIDS                object
# NationalPlayersCount      int64
# TeamSizeRatio           float64
# dtype: object

# %%
# Let us find unique values for "TeamCost" column without considering digits
complete_clubs_df["TeamCost"].str.replace(r"([\d]+)", "", regex=True).unique()
# Out:
# array([', млн €', ' тыс €', '-', ', Млрд. €'], dtype=object)

# %%
# Drop rows with missing values ("-" sign)
complete_clubs_df.drop(complete_clubs_df[complete_clubs_df["TeamCost"].str.contains("-")].index, inplace=True)

# %%
# Verify result
complete_clubs_df["TeamCost"].str.replace(r"([\d]+)", "", regex=True).unique()
# Out:
# array([', млн €', ' тыс €', ', Млрд. €'], dtype=object)

# %%
# Remove commas from string in "TeamCost" column, remove "тыс" (thousand), replace "млн" (million) with one zero because numbers that represent millions have exactly 2 float digits, and replace "Млрд." (billion) with 4 zeros, so that every number will represent amount of thousands in cost
complete_clubs_df.TeamCost = complete_clubs_df.TeamCost. \
    str.replace(",", "") \
    .str.replace("тыс", "") \
    .str.replace("млн", "0") \
    .str.replace("Млрд.", "0000") \
    .str.replace("€", "") \
    .str.replace(" ", "")
complete_clubs_df.head(15)
# Out:
#     TeamID  Year TeamCost AverageAge  Legioners  TeamSize  \
# 0     1002  2014     4250       21,5         16        39
# 1     1002  2015     3600       21,6         12        32
# 2     1002  2016     3480       21,0         10        38
# 3     1002  2017     3550       21,3          8        37
# 4     1002  2018     5800       22,4          9        39
# 5     1002  2019     4680       21,4          5        38
# 6     1002  2020     5150       21,0          3        40
# 7     1002  2021     5750       22,4          3        37
# 8     1002  2022     5060       22,3          3        38
# 9     1002  2023     5330       21,2          5        51
# 10    1002  2024     3480       22,0          1        30
# 11    1003  2014    66700       27,4         30        37
# 12    1003  2015   161100       27,3         31        35
# 13    1003  2016   218650       27,1         27        31
# 14    1003  2017   304250       27,0         28        34
#
#                                             PlayerIDS  NationalPlayersCount  \
# 0   [95621, 112797, 169963, 198986, 38793, 139304,...                    11
# 1   [112797, 169963, 198986, 38793, 133770, 133613...                     9
# 2   [112797, 169963, 198986, 324448, 133770, 13361...                    15
# 3   [112797, 169963, 198986, 324448, 363402, 13361...                    10
# 4   [198981, 112797, 169963, 198986, 324448, 36359...                    13
# 5   [198981, 324448, 169963, 363402, 549282, 73962...                    14
# 6   [198981, 324448, 242044, 363402, 739626, 24736...                    16
# 7   [198981, 324448, 242044, 363402, 402119, 57422...                    17
# 8   [242044, 324448, 363402, 402119, 198988, 24736...                    14
# 9   [363402, 402119, 324448, 488270, 927920, 24736...                    15
# 10  [402119, 363402, 488270, 927920, 898490, 48828...                    12
# 11  [16911, 67283, 3357, 163532, 27053, 2998, 1289...                     8
# 12  [16911, 67283, 3357, 257293, 2998, 214056, 504...                    13
# 13  [16911, 21327, 67283, 2998, 214056, 62945, 100...                    16
# 14  [16911, 2857, 67283, 177907, 59032, 214056, 10...                    13
#
#     TeamSizeRatio
# 0             NaN
# 1            0.82
# 2            1.19
# 3            0.97
# 4            1.05
# 5            0.97
# 6            1.05
# 7            0.93
# 8            1.03
# 9            1.34
# 10           0.59
# 11            NaN
# 12           0.95
# 13           0.89
# 14           1.10

# %%
# Merge two data frames to obtain clubs costs per year
countries_df = countries_df.merge(complete_clubs_df, left_on="TeamID", right_on="TeamID")
countries_df.head(15)
# Out:
#     NationalTeamID NationalTeamName  TeamID Country_Name  Year TeamCost  \
# 0             3377          Франция     583      Франция  2014   363900
# 1             3377          Франция     583      Франция  2015   436300
# 2             3377          Франция     583      Франция  2016   519000
# 3             3377          Франция     583      Франция  2017   900100
# 4             3377          Франция     583      Франция  2018  1010000
# 5             3377          Франция     583      Франция  2019   874150
# 6             3377          Франция     583      Франция  2020   805000
# 7             3377          Франция     583      Франция  2021   875150
# 8             3377          Франция     583      Франция  2022   891100
# 9             3377          Франция     583      Франция  2023  1020000
# 10            3377          Франция     583      Франция  2024   870500
# 11            3377          Франция    1082      Франция  2014    82650
# 12            3377          Франция    1082      Франция  2015    70800
# 13            3377          Франция    1082      Франция  2016    83900
# 14            3377          Франция    1082      Франция  2017    96750
#
#    AverageAge  Legioners  TeamSize  \
# 0        25,7         30        32
# 1        25,4         31        35
# 2        25,0         35        39
# 3        25,5         31        35
# 4        25,4         36        39
# 5        25,8         35        35
# 6        24,7         39        41
# 7        26,2         39        41
# 8        25,9         34        37
# 9        24,9         34        36
# 10       23,6         23        24
# 11       25,7         29        31
# 12       26,0         31        34
# 13       25,1         36        46
# 14       22,5         27        32
#
#                                             PlayerIDS  NationalPlayersCount  \
# 0   [25508, 18036, 182906, 164904, 29241, 46741, 1...                    16
# 1   [45672, 25508, 18036, 181767, 46741, 29241, 28...                    17
# 2   [45672, 120629, 25508, 282028, 181767, 46741, ...                    20
# 3   [120629, 45672, 282028, 395251, 181767, 282041...                    19
# 4   [120629, 45672, 282028, 5023, 395251, 181767, ...                    21
# 5   [120629, 45672, 79422, 207302, 465955, 460626,...                    20
# 6   [79422, 207302, 465955, 93730, 460626, 606576,...                    15
# 7   [315858, 79422, 207302, 93730, 460626, 606576,...                    19
# 8   [315858, 79422, 207302, 654408, 93730, 181767,...                    17
# 9   [315858, 466783, 79422, 207302, 93730, 810067,...                    18
# 10  [315858, 318470, 466783, 181767, 661171, 87217...                    17
# 11  [37760, 17348, 290537, 48859, 17179, 9659, 126...                    13
# 12  [37760, 182906, 17348, 290537, 82324, 30757, 1...                     8
# 13  [37760, 182906, 290537, 353366, 126673, 82324,...                    14
# 14  [182906, 415383, 258267, 126673, 191987, 27300...                     9
#
#     TeamSizeRatio
# 0             NaN
# 1            1.09
# 2            1.11
# 3            0.90
# 4            1.11
# 5            0.90
# 6            1.17
# 7            1.00
# 8            0.90
# 9            0.97
# 10           0.67
# 11            NaN
# 12           1.10
# 13           1.35
# 14           0.70

# %%
# Divide data into specific data frames
full_players_cost_df = countries_df[["NationalTeamID", "Year", "TeamID", "TeamCost"]]
full_players_cost_df.head(15)
# Out:
#     NationalTeamID  Year  TeamID TeamCost
# 0             3377  2014     583   363900
# 1             3377  2015     583   436300
# 2             3377  2016     583   519000
# 3             3377  2017     583   900100
# 4             3377  2018     583  1010000
# 5             3377  2019     583   874150
# 6             3377  2020     583   805000
# 7             3377  2021     583   875150
# 8             3377  2022     583   891100
# 9             3377  2023     583  1020000
# 10            3377  2024     583   870500
# 11            3377  2014    1082    82650
# 12            3377  2015    1082    70800
# 13            3377  2016    1082    83900
# 14            3377  2017    1082    96750

# %%
# Check data types
full_players_cost_df.dtypes
# Out:
# NationalTeamID     int64
# Year               int64
# TeamID             int64
# TeamCost          object
# dtype: object

# %%
# Check for missing values
full_players_cost_df.isna().sum()
# Out:
# NationalTeamID    0
# Year              0
# TeamID            0
# TeamCost          0
# dtype: int64

# %%
# Convert "TotalCost" column to integer
full_players_cost_df.loc[:, "TeamCost"] = full_players_cost_df.loc[:, "TeamCost"].astype(int)
full_players_cost_df.dtypes
# Out:
# NationalTeamID     int64
# Year               int64
# TeamID             int64
# TeamCost          object
# dtype: object

# %%
# Create another data frame for another metric, which is "average_team_cost"
average_team_cost_df = full_players_cost_df.groupby(["NationalTeamID", "Year"], as_index=False) \
    .agg({"TeamCost": "mean"}) \
    .rename(columns={"TotalCountryCost": "AverageCountryCost"}) \
    .sort_values(["NationalTeamID", "Year"])
    
average_team_cost_df.head(15)
# Out:
#     NationalTeamID  Year       TeamCost
# 0             3262  2014      140033.75
# 1             3262  2015     153685.625
# 2             3262  2016     166979.375
# 3             3262  2017      228828.75
# 4             3262  2018       279282.5
# 5             3262  2019     263208.125
# 6             3262  2020       284627.5
# 7             3262  2021      260271.25
# 8             3262  2022     275444.375
# 9             3262  2023     288541.875
# 10            3262  2024     265178.125
# 11            3299  2014       234580.0
# 12            3299  2015       265864.0
# 13            3299  2016       327566.0
# 14            3299  2017  473338.666667

# %%
# Write these results to a JSON file
with open("average_team_cost.json", "w") as file:
    json.dump(average_team_cost_df.to_dict(orient="records"), file, indent=4)

# %%
# Sum up costs of all players in clubs
full_players_cost_df = full_players_cost_df.groupby(["NationalTeamID", "Year"], as_index=False) \
    .agg({"TeamCost": "sum"}) \
    .rename(columns={"TeamCost": "TotalCountryCost"}) \
    .sort_values(["NationalTeamID", "Year"])
    
full_players_cost_df.head(15)
# Out:
#     NationalTeamID  Year TotalCountryCost
# 0             3262  2014          2240540
# 1             3262  2015          2458970
# 2             3262  2016          2671670
# 3             3262  2017          3661260
# 4             3262  2018          4468520
# 5             3262  2019          4211330
# 6             3262  2020          4554040
# 7             3262  2021          4164340
# 8             3262  2022          4407110
# 9             3262  2023          4616670
# 10            3262  2024          4242850
# 11            3299  2014          3518700
# 12            3299  2015          3987960
# 13            3299  2016          4913490
# 14            3299  2017          7100080

# %%
# Write these results to a JSON file

with open("full_players_costs.json", "w") as file:
    json.dump(full_players_cost_df.to_dict(orient="records"), file, indent=4)

# %%
# Extract data about national teams players
national_teams_players_df = countries_df[["NationalTeamID", "Year", "TeamID", "NationalPlayersCount"]]
national_teams_players_df.head(15)
# Out:
#     NationalTeamID  Year  TeamID  NationalPlayersCount
# 0             3377  2014     583                    16
# 1             3377  2015     583                    17
# 2             3377  2016     583                    20
# 3             3377  2017     583                    19
# 4             3377  2018     583                    21
# 5             3377  2019     583                    20
# 6             3377  2020     583                    15
# 7             3377  2021     583                    19
# 8             3377  2022     583                    17
# 9             3377  2023     583                    18
# 10            3377  2024     583                    17
# 11            3377  2014    1082                    13
# 12            3377  2015    1082                     8
# 13            3377  2016    1082                    14
# 14            3377  2017    1082                     9

# %%
# Check for missing values
national_teams_players_df.isna().sum()
# Out:
# NationalTeamID          0
# Year                    0
# TeamID                  0
# NationalPlayersCount    0
# dtype: int64

# %%
# Find number of national teams players within clubs per year for each country
national_teams_players_df = national_teams_players_df.groupby(["NationalTeamID", "Year"], as_index=False) \
    .agg({"NationalPlayersCount": "sum"}) \
    .sort_values(["NationalTeamID", "Year"])
    
national_teams_players_df.head(15)
# Out:
#     NationalTeamID  Year  NationalPlayersCount
# 0             3262  2014                   171
# 1             3262  2015                   160
# 2             3262  2016                   153
# 3             3262  2017                   152
# 4             3262  2018                   145
# 5             3262  2019                   165
# 6             3262  2020                   155
# 7             3262  2021                   184
# 8             3262  2022                   178
# 9             3262  2023                   180
# 10            3262  2024                   160
# 11            3299  2014                   218
# 12            3299  2015                   209
# 13            3299  2016                   257
# 14            3299  2017                   242

# %%
# Write these results to a JSON file
with open("national_teams_players_total_amount.json", "w") as file:
    json.dump(national_teams_players_df.to_dict(orient="records"), file, indent=4)

# %%
# Extract data about legionnaires
legionnaires_df = countries_df[["NationalTeamID", "Year", "TeamID", "Legioners"]]
legionnaires_df.head(15)
# Out:
#     NationalTeamID  Year  TeamID  Legioners
# 0             3377  2014     583         30
# 1             3377  2015     583         31
# 2             3377  2016     583         35
# 3             3377  2017     583         31
# 4             3377  2018     583         36
# 5             3377  2019     583         35
# 6             3377  2020     583         39
# 7             3377  2021     583         39
# 8             3377  2022     583         34
# 9             3377  2023     583         34
# 10            3377  2024     583         23
# 11            3377  2014    1082         29
# 12            3377  2015    1082         31
# 13            3377  2016    1082         36
# 14            3377  2017    1082         27

# %%
# Find number of legionnaires within clubs per year for each country
legionnaires_df = legionnaires_df.groupby(["NationalTeamID", "Year"], as_index=False) \
    .agg({"Legioners": "sum"}) \
    .sort_values(["NationalTeamID", "Year"]) \
    .rename(columns={"Legioners": "TotalLegionnairesAmount"})
    
legionnaires_df.head(15)
# Out:
#     NationalTeamID  Year  TotalLegionnairesAmount
# 0             3262  2014                      358
# 1             3262  2015                      360
# 2             3262  2016                      384
# 3             3262  2017                      367
# 4             3262  2018                      364
# 5             3262  2019                      372
# 6             3262  2020                      369
# 7             3262  2021                      381
# 8             3262  2022                      372
# 9             3262  2023                      362
# 10            3262  2024                      296
# 11            3299  2014                      476
# 12            3299  2015                      490
# 13            3299  2016                      504
# 14            3299  2017                      481

# %%
# Write these results to a JSON file
with open("legionnaires_total_amount.json", "w") as file:
    json.dump(legionnaires_df.to_dict(orient="records"), file, indent=4)

# %%
# Extract data about average age of players
average_age_df = countries_df[["NationalTeamID", "Year", "TeamID", "AverageAge"]]
average_age_df.head(15)
# Out:
#     NationalTeamID  Year  TeamID AverageAge
# 0             3377  2014     583       25,7
# 1             3377  2015     583       25,4
# 2             3377  2016     583       25,0
# 3             3377  2017     583       25,5
# 4             3377  2018     583       25,4
# 5             3377  2019     583       25,8
# 6             3377  2020     583       24,7
# 7             3377  2021     583       26,2
# 8             3377  2022     583       25,9
# 9             3377  2023     583       24,9
# 10            3377  2024     583       23,6
# 11            3377  2014    1082       25,7
# 12            3377  2015    1082       26,0
# 13            3377  2016    1082       25,1
# 14            3377  2017    1082       22,5

# %%
# Replace commas with dots in "AverageAge" column
average_age_df.loc[:, "AverageAge"] = average_age_df.loc[:, "AverageAge"].str.replace(",", ".")
average_age_df.head(15)
# Out:
#     NationalTeamID  Year  TeamID AverageAge
# 0             3377  2014     583       25.7
# 1             3377  2015     583       25.4
# 2             3377  2016     583       25.0
# 3             3377  2017     583       25.5
# 4             3377  2018     583       25.4
# 5             3377  2019     583       25.8
# 6             3377  2020     583       24.7
# 7             3377  2021     583       26.2
# 8             3377  2022     583       25.9
# 9             3377  2023     583       24.9
# 10            3377  2024     583       23.6
# 11            3377  2014    1082       25.7
# 12            3377  2015    1082       26.0
# 13            3377  2016    1082       25.1
# 14            3377  2017    1082       22.5

# %%
# Check data types
average_age_df.dtypes
# Out:
# NationalTeamID     int64
# Year               int64
# TeamID             int64
# AverageAge        object
# dtype: object

# %%
# Convert "AverageAge" column to float
average_age_df.loc[:, "AverageAge"] = average_age_df.loc[:, "AverageAge"].astype(float)
average_age_df.dtypes
# Out:
# NationalTeamID     int64
# Year               int64
# TeamID             int64
# AverageAge        object
# dtype: object

# %%
average_age_df.groupby(["NationalTeamID", "Year"], as_index=False) \
    .agg({"AverageAge": "mean"}) \
    .sort_values(["NationalTeamID", "Year"]) \
    .rename(columns={"AverageAge": "AverageAgeAmongClubs"})
# Out:
#      NationalTeamID  Year AverageAgeAmongClubs
# 0              3262  2014              25.5625
# 1              3262  2015              25.4375
# 2              3262  2016             25.20625
# 3              3262  2017             25.39375
# 4              3262  2018               25.275
# ..              ...   ...                  ...
# 556           53982  2020            25.822222
# 557           53982  2021            25.422222
# 558           53982  2022            25.411111
# 559           53982  2023            25.144444
# 560           53982  2024              25.3125
#
# [561 rows x 3 columns]

# %%
# Write these results to a JSON file
with open("total_average_age.json", "w") as file:
    json.dump(average_age_df.to_dict(orient="records"), file, indent=4)
